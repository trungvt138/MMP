# %% [markdown]
# ### Dieses Notebook zeigt ein einfaches Beispiel für ein flaches neuronales Netz zum Trainieren des MNIST-Datensatzes.
#
# Laden der nötigen Bibliotheken:

# %%
import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Flatten, Dense
from keras.optimizers import SGD, RMSprop, Adam 
from keras import regularizers
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Laden und Aufbereiten der Trainingsdaten:

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()
x_train = x_train / 255.0
x_test  = x_test / 255.0
y_train = keras.utils.to_categorical(y_train, 10)
y_test =  keras.utils.to_categorical(y_test,  10)

# %% [markdown]
# Definition des Neuronalen Netzes:
# (Probieren Sie aus, wie sich das Netz verhält, wenn man statt 'relu' 'tanh' oder 'sigmoid' als Aktivierungsfunktion verwendet und wenn man L2-Regularisierung hinzufügt)

# %%
model = Sequential([
    Flatten(input_shape = (28, 28)),
    Dense(1500, activation='relu'),
    Dense(1500, activation='relu', kernel_regularizer=regularizers.L2(0.005)),
    Dense(10, activation='softmax')])

# %% [markdown]
# Ausgabe der Netzstruktur:

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 784)               0
#
#  dense (Dense)               (None, 1500)              1177500
#
#  dense_1 (Dense)             (None, 1500)              2251500
#
#  dense_2 (Dense)             (None, 10)                15010
#
# =================================================================
# Total params: 3,444,010
# Trainable params: 3,444,010
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Erstellen des Netzes mit Optimierungsmethode (z.B. SGD, RMSprop oder Adam):

# %%
model.compile(loss='categorical_crossentropy',
              optimizer=Adam(),
              metrics=['accuracy'])

# %% [markdown]
# Trainineren des Netzes:

# %%
history = model.fit(x_train, y_train,
                    batch_size=6000,
                    epochs=50,
                    verbose=1,
                    validation_data=(x_test, y_test))
# Out:
# Epoch 1/50
# 10/10 [==============================] - 7s 686ms/step - loss: 7.0413 - accuracy: 0.7389 - val_loss: 4.9748 - val_accuracy: 0.8925
# Epoch 2/50
# 10/10 [==============================] - 6s 630ms/step - loss: 3.9206 - accuracy: 0.9086 - val_loss: 2.8061 - val_accuracy: 0.9235
# Epoch 3/50
# 10/10 [==============================] - 5s 544ms/step - loss: 2.1781 - accuracy: 0.9296 - val_loss: 1.5425 - val_accuracy: 0.9397
# Epoch 4/50
# 10/10 [==============================] - 6s 595ms/step - loss: 1.2090 - accuracy: 0.9429 - val_loss: 0.8737 - val_accuracy: 0.9465
# Epoch 5/50
# 10/10 [==============================] - 5s 518ms/step - loss: 0.7087 - accuracy: 0.9496 - val_loss: 0.5436 - val_accuracy: 0.9521
# Epoch 6/50
# 10/10 [==============================] - 5s 534ms/step - loss: 0.4595 - accuracy: 0.9548 - val_loss: 0.3798 - val_accuracy: 0.9558
# Epoch 7/50
# 10/10 [==============================] - 5s 505ms/step - loss: 0.3316 - accuracy: 0.9591 - val_loss: 0.2910 - val_accuracy: 0.9576
# Epoch 8/50
# 10/10 [==============================] - 5s 552ms/step - loss: 0.2604 - accuracy: 0.9633 - val_loss: 0.2347 - val_accuracy: 0.9634
# Epoch 9/50
# 10/10 [==============================] - 5s 506ms/step - loss: 0.2155 - accuracy: 0.9680 - val_loss: 0.2135 - val_accuracy: 0.9626
# Epoch 10/50
# 10/10 [==============================] - 5s 506ms/step - loss: 0.1967 - accuracy: 0.9665 - val_loss: 0.1902 - val_accuracy: 0.9650
# Epoch 11/50
# 10/10 [==============================] - 5s 470ms/step - loss: 0.1736 - accuracy: 0.9712 - val_loss: 0.1718 - val_accuracy: 0.9684
# Epoch 12/50
# 10/10 [==============================] - 5s 548ms/step - loss: 0.1598 - accuracy: 0.9728 - val_loss: 0.1726 - val_accuracy: 0.9657
# Epoch 13/50
# 10/10 [==============================] - 6s 564ms/step - loss: 0.1532 - accuracy: 0.9735 - val_loss: 0.1679 - val_accuracy: 0.9658
# Epoch 14/50
# 10/10 [==============================] - 5s 538ms/step - loss: 0.1444 - accuracy: 0.9750 - val_loss: 0.1476 - val_accuracy: 0.9715
# Epoch 15/50
# 10/10 [==============================] - 5s 517ms/step - loss: 0.1326 - accuracy: 0.9780 - val_loss: 0.1456 - val_accuracy: 0.9714
# Epoch 16/50
# 10/10 [==============================] - 5s 513ms/step - loss: 0.1283 - accuracy: 0.9781 - val_loss: 0.1384 - val_accuracy: 0.9739
# Epoch 17/50
# 10/10 [==============================] - 5s 532ms/step - loss: 0.1286 - accuracy: 0.9769 - val_loss: 0.1417 - val_accuracy: 0.9712
# Epoch 18/50
# 10/10 [==============================] - 5s 503ms/step - loss: 0.1216 - accuracy: 0.9800 - val_loss: 0.1340 - val_accuracy: 0.9729
# Epoch 19/50
# 10/10 [==============================] - 5s 522ms/step - loss: 0.1167 - accuracy: 0.9811 - val_loss: 0.1308 - val_accuracy: 0.9730
# Epoch 20/50
# 10/10 [==============================] - 5s 484ms/step - loss: 0.1110 - accuracy: 0.9816 - val_loss: 0.1280 - val_accuracy: 0.9748
# Epoch 21/50
# 10/10 [==============================] - 5s 501ms/step - loss: 0.1040 - accuracy: 0.9839 - val_loss: 0.1215 - val_accuracy: 0.9768
# Epoch 22/50
# 10/10 [==============================] - 5s 530ms/step - loss: 0.1018 - accuracy: 0.9839 - val_loss: 0.1200 - val_accuracy: 0.9762
# Epoch 23/50
# 10/10 [==============================] - 5s 524ms/step - loss: 0.1042 - accuracy: 0.9824 - val_loss: 0.1234 - val_accuracy: 0.9748
# Epoch 24/50
# 10/10 [==============================] - 5s 521ms/step - loss: 0.0994 - accuracy: 0.9845 - val_loss: 0.1173 - val_accuracy: 0.9762
# Epoch 25/50
# 10/10 [==============================] - 5s 490ms/step - loss: 0.0951 - accuracy: 0.9855 - val_loss: 0.1195 - val_accuracy: 0.9753
# Epoch 26/50
# 10/10 [==============================] - 5s 500ms/step - loss: 0.0942 - accuracy: 0.9853 - val_loss: 0.1189 - val_accuracy: 0.9739
# Epoch 27/50
# 10/10 [==============================] - 6s 580ms/step - loss: 0.0904 - accuracy: 0.9864 - val_loss: 0.1185 - val_accuracy: 0.9752
# Epoch 28/50
# 10/10 [==============================] - 5s 511ms/step - loss: 0.0884 - accuracy: 0.9859 - val_loss: 0.1134 - val_accuracy: 0.9758
# Epoch 29/50
# 10/10 [==============================] - 5s 510ms/step - loss: 0.0860 - accuracy: 0.9873 - val_loss: 0.1071 - val_accuracy: 0.9775
# Epoch 30/50
# 10/10 [==============================] - 5s 509ms/step - loss: 0.0833 - accuracy: 0.9874 - val_loss: 0.1025 - val_accuracy: 0.9800
# Epoch 31/50
# 10/10 [==============================] - 5s 540ms/step - loss: 0.0774 - accuracy: 0.9897 - val_loss: 0.1028 - val_accuracy: 0.9785
# Epoch 32/50
# 10/10 [==============================] - 5s 509ms/step - loss: 0.0748 - accuracy: 0.9903 - val_loss: 0.1032 - val_accuracy: 0.9776
# Epoch 33/50
# 10/10 [==============================] - 5s 536ms/step - loss: 0.0766 - accuracy: 0.9886 - val_loss: 0.1096 - val_accuracy: 0.9748
# Epoch 34/50
# 10/10 [==============================] - 5s 498ms/step - loss: 0.0772 - accuracy: 0.9887 - val_loss: 0.1062 - val_accuracy: 0.9764
# Epoch 35/50
# 10/10 [==============================] - 5s 484ms/step - loss: 0.0745 - accuracy: 0.9894 - val_loss: 0.1077 - val_accuracy: 0.9762
# Epoch 36/50
# 10/10 [==============================] - 5s 548ms/step - loss: 0.0760 - accuracy: 0.9889 - val_loss: 0.1004 - val_accuracy: 0.9793
# Epoch 37/50
# 10/10 [==============================] - 5s 543ms/step - loss: 0.0702 - accuracy: 0.9912 - val_loss: 0.0982 - val_accuracy: 0.9796
# Epoch 38/50
# 10/10 [==============================] - 5s 525ms/step - loss: 0.0702 - accuracy: 0.9903 - val_loss: 0.1052 - val_accuracy: 0.9781
# Epoch 39/50
# 10/10 [==============================] - 5s 480ms/step - loss: 0.0725 - accuracy: 0.9894 - val_loss: 0.1136 - val_accuracy: 0.9745
# Epoch 40/50
# 10/10 [==============================] - 5s 488ms/step - loss: 0.0785 - accuracy: 0.9876 - val_loss: 0.1014 - val_accuracy: 0.9796
# Epoch 41/50
# 10/10 [==============================] - 6s 563ms/step - loss: 0.0688 - accuracy: 0.9909 - val_loss: 0.1035 - val_accuracy: 0.9775
# Epoch 42/50
# 10/10 [==============================] - 5s 537ms/step - loss: 0.0683 - accuracy: 0.9905 - val_loss: 0.0966 - val_accuracy: 0.9782
# Epoch 43/50
# 10/10 [==============================] - 5s 544ms/step - loss: 0.0702 - accuracy: 0.9893 - val_loss: 0.1092 - val_accuracy: 0.9755
# Epoch 44/50
# 10/10 [==============================] - 5s 522ms/step - loss: 0.0738 - accuracy: 0.9887 - val_loss: 0.1037 - val_accuracy: 0.9781
# Epoch 45/50
# 10/10 [==============================] - 5s 504ms/step - loss: 0.0678 - accuracy: 0.9913 - val_loss: 0.1012 - val_accuracy: 0.9784
# Epoch 46/50
# 10/10 [==============================] - 6s 564ms/step - loss: 0.0616 - accuracy: 0.9929 - val_loss: 0.0938 - val_accuracy: 0.9786
# Epoch 47/50
# 10/10 [==============================] - 5s 513ms/step - loss: 0.0575 - accuracy: 0.9936 - val_loss: 0.0895 - val_accuracy: 0.9799
# Epoch 48/50
# 10/10 [==============================] - 5s 544ms/step - loss: 0.0569 - accuracy: 0.9938 - val_loss: 0.0938 - val_accuracy: 0.9797
# Epoch 49/50
# 10/10 [==============================] - 5s 538ms/step - loss: 0.0561 - accuracy: 0.9939 - val_loss: 0.0874 - val_accuracy: 0.9817
# Epoch 50/50
# 10/10 [==============================] - 5s 552ms/step - loss: 0.0530 - accuracy: 0.9944 - val_loss: 0.0861 - val_accuracy: 0.9816

# %% [markdown]
# Berechnen und Bewerten der Netzausgabe nach dem Training:

# %%
score = model.evaluate(x_test, y_test, verbose=0)
print()
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Test loss: 0.08612620830535889
# Test accuracy: 0.9815999865531921

# %% [markdown]
# Ausgabe des Netzfehlers während des Trainingsverlaufes (fuer Trainingsdaten und Testdaten):

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# Ausgabe der Netz-Accuracy waehrend des Trainingsverlaufes (fuer Trainingsdaten und Testdaten):

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='lower right')
plt.show()

# %% [markdown]
# Ausgabe der falsch klassifizierten Testdaten-Bilder:

# %%
pred = model.predict(x_test)
mask = ~(np.argmax(pred,axis=1)==np.argmax(y_test,axis=1))
wrong_pred=pred[mask,:]
wrong_label=np.argmax(wrong_pred,axis=1)
wrong_y=y_test[mask,:]
wrong_x=x_test[mask,:,:]
print(wrong_pred.shape[0],'out of',pred.shape[0],'false classifications in test dataset (',int(wrong_pred.shape[0]/pred.shape[0]*10000)/100,'% )')

for i in range(wrong_y.shape[0]):
    plt.imshow(1-wrong_x[i,:,:],cmap='gray')
    plt.title(str(np.argmax(wrong_y[i,:]))+' detected as '+str(wrong_label[i]))
    plt.axis('off')
    plt.show()
# Out:
# 313/313 [==============================] - 2s 5ms/step
# 184 out of 10000 false classifications in test dataset ( 1.84 % )
